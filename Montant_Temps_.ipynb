# %% [markdown]
# <h1><center> Traitement, Visualisation et Analyse des données - Partie II </center></h1>

# %% [markdown]
# # 4 - Visualisation de données

# %% [markdown]
# ## 4.1 Configurations

# %%
import pandas as pd 
import numpy as np
from matplotlib.pyplot import plot as plt

# %% [markdown]
# ## 4.2 Charger le graphique

# %%
df = pd.read_csv("Data/Montant_Temps.csv")
df
# Out:
#     Montant_du_capitale  Temps
# 0                     1      5
# 1                    12      6
# 2                    13      7
# 3                     2      8
# 4                     3      9
# 5                     0     10
# 6                     1     11
# 7                     6     12
# 8                     7     13
# 9                     4     14
# 10                    5     15
# 11                   26     16
# 12                   27     17
# 13                   24     18
# 14                   25     19
# 15                   30     20
# 16                   31     21
# 17                   28     22
# 18                   29     23
# 19                   18     24
# 20                   19     25
# 21                   16     26
# 22                   17     27
# 23                   22     28
# 24                   23     29
# 25                   20     30
# 26                   21     31
# 27                   42     32
# 28                   43     33
# ...

# %% [markdown]
# ## 4.3 Découpage des données

# %%
#On utilise la fonction '.iloc'
capital = df.iloc[:,0]
temps = df.iloc[:,1]
capital, temps
# Out:
# (0      1
#  1     12
#  2     13
#  3      2
#  4      3
#  5      0
#  6      1
#  7      6
#  8      7
#  9      4
#  10     5
#  11    26
#  12    27
#  13    24
#  14    25
#  15    30
#  16    31
#  17    28
#  18    29
#  19    18
#  20    19
#  21    16
#  22    17
#  23    22
#  24    23
#  25    20
#  26    21
#  27    42
#  28    43
#  29    40
#  30    41
#  31    46
#  32    47
#  33    44
#  34    45
#  35    34
#  36    35
#  37    32
#  38    33
#  39    38
#  40    39
#  41    36
#  42    37
#  43    58
#  44    59
#  Name: Montant_du_capitale, dtype: int64,
#  0      5
#  1      6
#  2      7
#  3      8
#  4      9
#  5     10
#  6     11
#  7     12
#  8     13
#  9     14
#  10    15
#  11    16
#  12    17
#  13    18
#  14    19
#  15    20
#  16    21
#  17    22
#  18    23
#  19    24
#  20    25
#  21    26
#  22    27
#  23    28
#  24    29
#  25    30
#  26    31
#  27    32
#  28    33
#  29    34
#  30    35
#  31    36
#  32    37
#  33    38
# ...

# %%
plt(temps, capital)

# %% [markdown]
# ### 4.4 - Visualisation de données sous forme de nuage de points

# %%
df.plot.scatter('Temps', 'Montant_du_capitale')
